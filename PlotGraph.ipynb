# %%
import matplotlib.pyplot as plt
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix
from ModelPrediction import init_split_data, prediction

# %%
data = init_split_data()

prediction(data)
# Out:
# 20-Mar-24 18:01:33 - locator: <matplotlib.ticker.AutoLocator object at 0x16d34b710>
# 20-Mar-24 18:01:34 - locator: <matplotlib.ticker.AutoLocator object at 0x16d3d5190>
# 20-Mar-24 18:01:35 - locator: <matplotlib.ticker.AutoLocator object at 0x16d247c10>
